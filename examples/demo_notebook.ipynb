# %% [markdown]
# # EE MVP Demo Notebook
# Install the package in editable mode when running on Colab.

# %%
# !pip install -q -e .

# %%
from pathlib import Path
from ee_mvp import analyze, DEFAULT_CONFIG
project_path = Path('examples/demo_project.json')
results = analyze(project_path, DEFAULT_CONFIG, write_csv=True)
for name, frame in results.items():
    print(f'\n=== {name} ===')
    display(frame)
